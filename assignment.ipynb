# %%
pip install opencv-python ultralytics deep_sort_realtime
# Out:
# Requirement already satisfied: opencv-python in c:\users\hp\appdata\roaming\python\python311\site-packages (4.10.0.84)
# Requirement already satisfied: ultralytics in c:\users\hp\appdata\roaming\python\python311\site-packages (8.2.102)
# Collecting deep_sort_realtime
#   Downloading deep_sort_realtime-1.3.2-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\hp\anaconda3\lib\site-packages (from opencv-python) (1.24.4)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\hp\appdata\roaming\python\python311\site-packages (from ultralytics) (3.9.2)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\hp\appdata\roaming\python\python311\site-packages (from ultralytics) (10.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\hp\appdata\roaming\python\python311\site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\hp\appdata\roaming\python\python311\site-packages (from ultralytics) (1.14.1)
# Requirement already satisfied: torch>=1.8.0 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics) (2.6.0)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics) (0.21.0)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics) (4.65.0)
# Requirement already satisfied: psutil in c:\users\hp\appdata\roaming\python\python311\site-packages (from ultralytics) (5.9.8)
# Requirement already satisfied: py-cpuinfo in c:\users\hp\appdata\roaming\python\python311\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics) (1.5.3)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\hp\appdata\roaming\python\python311\site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in c:\users\hp\appdata\roaming\python\python311\site-packages (from ultralytics) (2.0.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\appdata\roaming\python\python311\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\appdata\roaming\python\python311\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\appdata\roaming\python\python311\site-packages (from matplotlib>=3.3.0->ultralytics) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hp\appdata\roaming\python\python311\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\appdata\roaming\python\python311\site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\appdata\roaming\python\python311\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\appdata\roaming\python\python311\site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2024.2.2)
# Requirement already satisfied: filelock in c:\users\hp\appdata\roaming\python\python311\site-packages (from torch>=1.8.0->ultralytics) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\hp\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (4.13.2)
# Requirement already satisfied: networkx in c:\users\hp\appdata\roaming\python\python311\site-packages (from torch>=1.8.0->ultralytics) (3.3)
# Requirement already satisfied: jinja2 in c:\users\hp\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\hp\appdata\roaming\python\python311\site-packages (from torch>=1.8.0->ultralytics) (2024.9.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\hp\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\hp\appdata\roaming\python\python311\site-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hp\anaconda3\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.3)
# Downloading deep_sort_realtime-1.3.2-py3-none-any.whl (8.4 MB)
#    ---------------------------------------- 0.0/8.4 MB ? eta -:--:--
#    ---- ----------------------------------- 1.0/8.4 MB 8.5 MB/s eta 0:00:01
#    ----------- ---------------------------- 2.4/8.4 MB 7.1 MB/s eta 0:00:01
#    ----------------- ---------------------- 3.7/8.4 MB 6.8 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.0/8.4 MB 6.4 MB/s eta 0:00:01
#    --------------------------- ------------ 5.8/8.4 MB 5.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.3/8.4 MB 5.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.3/8.4 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------  8.4/8.4 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------- 8.4/8.4 MB 4.7 MB/s eta 0:00:00
# Installing collected packages: deep_sort_realtime
# Successfully installed deep_sort_realtime-1.3.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip uninstall backports
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping backports as it is not installed.

# %%
import cv2
import torch
import numpy as np
from ultralytics import YOLO
from deep_sort_realtime.deepsort_tracker import DeepSort
import os
import time
from pathlib import Path
import random

# === CONFIGURATION ===
MODEL_PATH = Path(r'C:/Users/hp/Downloads/best.pt')
VIDEO_PATH = Path(r'C:/Users/hp/Downloads/15sec_input_720p.mp4')
OUTPUT_VIDEO_PATH = Path(rf'output_tracked_{int(time.time())}.mp4')

MAX_AGE = 60
N_INIT = 3
MAX_COSINE_DISTANCE = 0.2
YOLO_CONF_THRESH = 0.4
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'

# === COLOR MEMORY ===
id_colors = {}
def get_color(track_id):
    if track_id not in id_colors:
        id_colors[track_id] = tuple(random.randint(0, 255) for _ in range(3))
    return id_colors[track_id]

# === LOAD MODEL ===
print("[INFO] Loading YOLOv11 model...")
try:
    model = YOLO(str(MODEL_PATH))
except Exception as e:
    raise RuntimeError(f"Error loading YOLO model: {e}")

# === TRACKER INIT ===
print(f"[INFO] Initializing DeepSort (max_age={MAX_AGE}, n_init={N_INIT})...")
tracker = DeepSort(max_age=MAX_AGE, n_init=N_INIT, max_cosine_distance=MAX_COSINE_DISTANCE)

# === VIDEO CAPTURE ===
print(f"[INFO] Opening video file: {VIDEO_PATH}")
cap = cv2.VideoCapture(str(VIDEO_PATH))
if not cap.isOpened():
    raise RuntimeError(f"Failed to open video: {VIDEO_PATH}")

width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)
frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

print(f"[INFO] Video - Width: {width}, Height: {height}, FPS: {fps}, Frames: {frame_count}")

# === OUTPUT VIDEO ===
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(str(OUTPUT_VIDEO_PATH), fourcc, fps, (width, height))

# === TRACKING LOOP ===
frame_idx = 0
player_log = {}
start_time = time.time()

print("[INFO] Tracking started. Press 'q' to stop early.")
while True:
    ret, frame = cap.read()
    if not ret:
        print("[INFO] End of video reached.")
        break
    frame_idx += 1

    # Optional resizing to speed up (comment out if not needed)
    # frame = cv2.resize(frame, (width // 2, height // 2))

    try:
        results = model.predict(source=frame, conf=YOLO_CONF_THRESH, device=DEVICE)
    except Exception as e:
        print(f"[WARN] YOLO inference failed at frame {frame_idx}: {e}")
        continue

    detections = results[0].boxes.data.cpu().numpy()
    dets_for_tracker = []

    for det in detections:
        x1, y1, x2, y2, conf, cls = det
        class_id = int(cls)
        class_name = model.names[class_id].lower()
        if class_name == 'player':
            bbox = [x1, y1, x2 - x1, y2 - y1]
            dets_for_tracker.append((bbox, conf, class_name))

    tracks = tracker.update_tracks(dets_for_tracker, frame=frame)

    for track in tracks:
        if not track.is_confirmed() or track.is_deleted():
            continue
        if track.time_since_update > 0:
            continue

        track_id = track.track_id
        x1, y1, x2, y2 = map(int, track.to_ltrb())
        color = get_color(track_id)

        cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
        label = f"Player {track_id}"
        cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)

        if track_id not in player_log:
            player_log[track_id] = []
        player_log[track_id].append(frame_idx)

    out.write(frame)

    cv2.imshow("Player Re-ID & Tracking", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        print("[INFO] Interrupted by user.")
        break

    if frame_idx % 50 == 0:
        elapsed = time.time() - start_time
        print(f"[INFO] Processed {frame_idx}/{frame_count} frames ({frame_idx / elapsed:.2f} FPS)")

# === CLEANUP ===
cap.release()
out.release()
cv2.destroyAllWindows()

output_path = os.path.abspath(OUTPUT_VIDEO_PATH)
print(f"[INFO] Output video saved to: {output_path}")

log_path = Path('player_log.txt')
with open(log_path, 'w') as f:
    for pid, frames in player_log.items():
        f.write(f"Player {pid}: Frames {','.join(map(str, frames))}\n")

print(f"[INFO] Player log saved to: {log_path.resolve()}")
print("[INFO] All processing complete.")
# Out:
# [INFO] Loading YOLOv11 model...
# [INFO] Initializing DeepSort (max_age=60, n_init=3)...
# [INFO] Opening video file: C:\Users\hp\Downloads\15sec_input_720p.mp4
# [INFO] Video - Width: 1280, Height: 720, FPS: 25.0, Frames: 375
# [INFO] Tracking started. Press 'q' to stop early.
#
# 0: 384x640 1 ball, 16 players, 2 referees, 2104.0ms
# Speed: 57.6ms preprocess, 2104.0ms inference, 31.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 2 referees, 3062.2ms
# Speed: 137.4ms preprocess, 3062.2ms inference, 40.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 2 referees, 2254.1ms
# Speed: 11.2ms preprocess, 2254.1ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 1 referee, 1960.3ms
# Speed: 4.2ms preprocess, 1960.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 1748.0ms
# Speed: 4.1ms preprocess, 1748.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 2 referees, 1715.8ms
# Speed: 10.4ms preprocess, 1715.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 2175.5ms
# Speed: 8.6ms preprocess, 2175.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 2025.1ms
# Speed: 3.7ms preprocess, 2025.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 2086.8ms
# Speed: 22.9ms preprocess, 2086.8ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 2180.7ms
# Speed: 5.6ms preprocess, 2180.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 2052.5ms
# Speed: 7.0ms preprocess, 2052.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 1914.7ms
# Speed: 38.6ms preprocess, 1914.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 2 referees, 1751.5ms
# Speed: 4.1ms preprocess, 1751.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 1939.6ms
# Speed: 3.7ms preprocess, 1939.6ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 1748.2ms
# Speed: 7.1ms preprocess, 1748.2ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 2 referees, 1712.6ms
# Speed: 4.2ms preprocess, 1712.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 2021.5ms
# Speed: 4.9ms preprocess, 2021.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 1846.3ms
# Speed: 3.5ms preprocess, 1846.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 1856.9ms
# Speed: 8.0ms preprocess, 1856.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 1806.9ms
# Speed: 10.9ms preprocess, 1806.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1 referee, 1829.5ms
# Speed: 4.6ms preprocess, 1829.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 4 referees, 1964.8ms
# Speed: 3.0ms preprocess, 1964.8ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 3 referees, 2416.8ms
# Speed: 4.2ms preprocess, 2416.8ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 3 referees, 3114.1ms
# Speed: 10.9ms preprocess, 3114.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 2148.9ms
# Speed: 5.8ms preprocess, 2148.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 2791.6ms
# Speed: 7.9ms preprocess, 2791.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 3 referees, 2346.5ms
# Speed: 8.5ms preprocess, 2346.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 2 referees, 2119.3ms
# Speed: 5.8ms preprocess, 2119.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 2 referees, 2002.0ms
# Speed: 7.1ms preprocess, 2002.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 1982.1ms
# Speed: 4.9ms preprocess, 1982.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 2007.9ms
# Speed: 8.7ms preprocess, 2007.9ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 2 referees, 2310.6ms
# Speed: 3.6ms preprocess, 2310.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 2082.4ms
# Speed: 4.3ms preprocess, 2082.4ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 2246.7ms
# Speed: 12.2ms preprocess, 2246.7ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 2 referees, 2180.7ms
# Speed: 82.2ms preprocess, 2180.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 2 referees, 2166.3ms
# Speed: 4.4ms preprocess, 2166.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 2730.5ms
# Speed: 4.9ms preprocess, 2730.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 2583.7ms
# Speed: 132.2ms preprocess, 2583.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 2806.9ms
# Speed: 26.1ms preprocess, 2806.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 18 players, 3 referees, 2570.0ms
# Speed: 122.6ms preprocess, 2570.0ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 3 referees, 2079.5ms
# Speed: 4.3ms preprocess, 2079.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 3 referees, 1997.6ms
# Speed: 3.6ms preprocess, 1997.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 2532.0ms
# Speed: 4.6ms preprocess, 2532.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 2048.9ms
# Speed: 7.3ms preprocess, 2048.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 2 referees, 2078.9ms
# Speed: 8.0ms preprocess, 2078.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 2773.3ms
# Speed: 6.9ms preprocess, 2773.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 3 referees, 2549.5ms
# Speed: 21.1ms preprocess, 2549.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 2811.7ms
# Speed: 5.3ms preprocess, 2811.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 2172.6ms
# Speed: 36.7ms preprocess, 2172.6ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 3 referees, 2537.3ms
# Speed: 4.3ms preprocess, 2537.3ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Processed 50/375 frames (0.28 FPS)
#
# 0: 384x640 16 players, 2 referees, 2072.7ms
# Speed: 4.5ms preprocess, 2072.7ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 3 referees, 1743.5ms
# Speed: 5.8ms preprocess, 1743.5ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 3 referees, 2228.8ms
# Speed: 5.6ms preprocess, 2228.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 3 referees, 1958.3ms
# Speed: 7.4ms preprocess, 1958.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 4 referees, 2257.7ms
# Speed: 4.8ms preprocess, 2257.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 2 referees, 1933.3ms
# Speed: 8.5ms preprocess, 1933.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 2 referees, 1940.7ms
# Speed: 6.2ms preprocess, 1940.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 2 referees, 1772.0ms
# Speed: 4.1ms preprocess, 1772.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 1772.2ms
# Speed: 6.9ms preprocess, 1772.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 1691.5ms
# Speed: 4.2ms preprocess, 1691.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 1857.5ms
# Speed: 6.2ms preprocess, 1857.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 1862.7ms
# Speed: 4.3ms preprocess, 1862.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 1733.5ms
# Speed: 4.2ms preprocess, 1733.5ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 1816.9ms
# Speed: 4.5ms preprocess, 1816.9ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 3 referees, 1605.9ms
# Speed: 3.5ms preprocess, 1605.9ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 4 referees, 1766.3ms
# Speed: 3.7ms preprocess, 1766.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 3 referees, 1929.8ms
# Speed: 5.2ms preprocess, 1929.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 3 referees, 1711.3ms
# Speed: 8.5ms preprocess, 1711.3ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 1743.0ms
# Speed: 5.0ms preprocess, 1743.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 1784.7ms
# Speed: 6.5ms preprocess, 1784.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 1781.7ms
# Speed: 6.3ms preprocess, 1781.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 1946.9ms
# Speed: 5.5ms preprocess, 1946.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 1683.5ms
# Speed: 3.7ms preprocess, 1683.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 1731.8ms
# Speed: 3.6ms preprocess, 1731.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 1753.4ms
# Speed: 3.5ms preprocess, 1753.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 1787.5ms
# Speed: 8.1ms preprocess, 1787.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 1782.6ms
# Speed: 3.6ms preprocess, 1782.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 1 referee, 1651.7ms
# Speed: 4.3ms preprocess, 1651.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 2 referees, 1898.7ms
# Speed: 3.7ms preprocess, 1898.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 2 referees, 1832.4ms
# Speed: 9.4ms preprocess, 1832.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 1858.9ms
# Speed: 5.0ms preprocess, 1858.9ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 1781.4ms
# Speed: 3.5ms preprocess, 1781.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 1728.8ms
# Speed: 6.4ms preprocess, 1728.8ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 1766.8ms
# Speed: 3.5ms preprocess, 1766.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 1710.0ms
# Speed: 4.2ms preprocess, 1710.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 1546.9ms
# Speed: 3.7ms preprocess, 1546.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 1805.0ms
# Speed: 4.3ms preprocess, 1805.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 1722.5ms
# Speed: 10.9ms preprocess, 1722.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 1612.0ms
# Speed: 4.2ms preprocess, 1612.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 1977.9ms
# Speed: 3.1ms preprocess, 1977.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 1 referee, 1733.2ms
# Speed: 3.6ms preprocess, 1733.2ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 18 players, 3 referees, 1636.8ms
# Speed: 8.1ms preprocess, 1636.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 1831.4ms
# Speed: 3.5ms preprocess, 1831.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 1828.1ms
# Speed: 8.1ms preprocess, 1828.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 18 players, 2 referees, 1673.9ms
# Speed: 3.0ms preprocess, 1673.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 1705.2ms
# Speed: 7.1ms preprocess, 1705.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 1580.1ms
# Speed: 5.2ms preprocess, 1580.1ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 18 players, 2 referees, 1774.3ms
# Speed: 6.3ms preprocess, 1774.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 18 players, 3 referees, 1765.1ms
# Speed: 123.3ms preprocess, 1765.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 2010.2ms
# Speed: 4.3ms preprocess, 2010.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Processed 100/375 frames (0.32 FPS)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 1759.5ms
# Speed: 4.2ms preprocess, 1759.5ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 1 referee, 1795.8ms
# Speed: 3.7ms preprocess, 1795.8ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 2035.0ms
# Speed: 14.3ms preprocess, 2035.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 1958.5ms
# Speed: 8.5ms preprocess, 1958.5ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 1 referee, 1718.7ms
# Speed: 3.6ms preprocess, 1718.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 2701.8ms
# Speed: 4.6ms preprocess, 2701.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 2285.6ms
# Speed: 13.4ms preprocess, 2285.6ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 1 referee, 1935.6ms
# Speed: 8.2ms preprocess, 1935.6ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1967.9ms
# Speed: 4.1ms preprocess, 1967.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 1870.7ms
# Speed: 5.6ms preprocess, 1870.7ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 17 players, 1926.9ms
# Speed: 4.9ms preprocess, 1926.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 1983.4ms
# Speed: 6.5ms preprocess, 1983.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1 referee, 1836.0ms
# Speed: 29.3ms preprocess, 1836.0ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 2025.7ms
# Speed: 5.0ms preprocess, 2025.7ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 1790.2ms
# Speed: 3.8ms preprocess, 1790.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 1819.5ms
# Speed: 3.8ms preprocess, 1819.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 1779.5ms
# Speed: 3.8ms preprocess, 1779.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 1857.5ms
# Speed: 6.2ms preprocess, 1857.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 1 referee, 1863.1ms
# Speed: 3.7ms preprocess, 1863.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1 referee, 1806.0ms
# Speed: 5.8ms preprocess, 1806.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 1 referee, 1673.4ms
# Speed: 4.4ms preprocess, 1673.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 1 referee, 1757.2ms
# Speed: 6.0ms preprocess, 1757.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 1 referee, 1715.3ms
# Speed: 4.2ms preprocess, 1715.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 1703.0ms
# Speed: 7.7ms preprocess, 1703.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1 referee, 1737.5ms
# Speed: 4.4ms preprocess, 1737.5ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 1673.1ms
# Speed: 3.9ms preprocess, 1673.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 1739.7ms
# Speed: 2.9ms preprocess, 1739.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 1731.0ms
# Speed: 4.1ms preprocess, 1731.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 1 referee, 1741.9ms
# Speed: 3.5ms preprocess, 1741.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 1 referee, 1888.2ms
# Speed: 4.2ms preprocess, 1888.2ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 1 referee, 1722.3ms
# Speed: 7.8ms preprocess, 1722.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 1 referee, 1915.4ms
# Speed: 5.7ms preprocess, 1915.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 17 players, 1 referee, 1819.3ms
# Speed: 6.4ms preprocess, 1819.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1 referee, 2018.2ms
# Speed: 7.1ms preprocess, 2018.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 1868.1ms
# Speed: 6.5ms preprocess, 1868.1ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 1798.6ms
# Speed: 12.0ms preprocess, 1798.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 1 referee, 1748.9ms
# Speed: 6.9ms preprocess, 1748.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 1 referee, 1813.1ms
# Speed: 4.1ms preprocess, 1813.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 1 referee, 1800.6ms
# Speed: 4.1ms preprocess, 1800.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1 referee, 1834.0ms
# Speed: 3.0ms preprocess, 1834.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 1666.4ms
# Speed: 3.7ms preprocess, 1666.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 1779.0ms
# Speed: 3.6ms preprocess, 1779.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2034.2ms
# Speed: 3.7ms preprocess, 2034.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1 referee, 1920.7ms
# Speed: 3.7ms preprocess, 1920.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1 referee, 2136.3ms
# Speed: 5.7ms preprocess, 2136.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 2 referees, 1804.0ms
# Speed: 7.2ms preprocess, 1804.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 1 referee, 1816.7ms
# Speed: 10.3ms preprocess, 1816.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 1 referee, 1873.8ms
# Speed: 8.2ms preprocess, 1873.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1 referee, 1820.3ms
# Speed: 5.7ms preprocess, 1820.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1 referee, 1691.5ms
# Speed: 3.6ms preprocess, 1691.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Processed 150/375 frames (0.33 FPS)
#
# 0: 384x640 1 ball, 13 players, 1 referee, 1887.5ms
# Speed: 5.6ms preprocess, 1887.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 1 referee, 1956.5ms
# Speed: 7.1ms preprocess, 1956.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 1 referee, 1766.7ms
# Speed: 4.2ms preprocess, 1766.7ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 1 referee, 1859.4ms
# Speed: 4.0ms preprocess, 1859.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 1 referee, 1961.2ms
# Speed: 5.1ms preprocess, 1961.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1 referee, 1847.1ms
# Speed: 6.6ms preprocess, 1847.1ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1 referee, 1688.1ms
# Speed: 7.6ms preprocess, 1688.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 1 referee, 1732.7ms
# Speed: 3.1ms preprocess, 1732.7ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1 referee, 1646.6ms
# Speed: 14.2ms preprocess, 1646.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1 referee, 1692.0ms
# Speed: 3.5ms preprocess, 1692.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 1701.3ms
# Speed: 3.3ms preprocess, 1701.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1 referee, 1721.3ms
# Speed: 5.5ms preprocess, 1721.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1 referee, 1726.2ms
# Speed: 7.0ms preprocess, 1726.2ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1 referee, 1810.1ms
# Speed: 3.0ms preprocess, 1810.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1 referee, 1790.8ms
# Speed: 7.4ms preprocess, 1790.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1 referee, 1684.5ms
# Speed: 6.8ms preprocess, 1684.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1 referee, 1649.7ms
# Speed: 7.2ms preprocess, 1649.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 1753.2ms
# Speed: 3.6ms preprocess, 1753.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 1710.0ms
# Speed: 7.0ms preprocess, 1710.0ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 1648.3ms
# Speed: 3.1ms preprocess, 1648.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1744.0ms
# Speed: 7.7ms preprocess, 1744.0ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1 referee, 1814.0ms
# Speed: 8.8ms preprocess, 1814.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1 referee, 1678.1ms
# Speed: 3.6ms preprocess, 1678.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1 referee, 1747.4ms
# Speed: 2.5ms preprocess, 1747.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1723.0ms
# Speed: 5.2ms preprocess, 1723.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1733.3ms
# Speed: 8.9ms preprocess, 1733.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1637.8ms
# Speed: 4.6ms preprocess, 1637.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1681.5ms
# Speed: 7.0ms preprocess, 1681.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1 referee, 1598.8ms
# Speed: 3.8ms preprocess, 1598.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 11 players, 1 referee, 1561.1ms
# Speed: 6.3ms preprocess, 1561.1ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 1580.3ms
# Speed: 7.4ms preprocess, 1580.3ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1 referee, 1644.6ms
# Speed: 4.6ms preprocess, 1644.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 1619.4ms
# Speed: 4.3ms preprocess, 1619.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1 referee, 1614.7ms
# Speed: 4.9ms preprocess, 1614.7ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1737.7ms
# Speed: 5.3ms preprocess, 1737.7ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1739.5ms
# Speed: 5.3ms preprocess, 1739.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 1595.8ms
# Speed: 3.9ms preprocess, 1595.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 1 referee, 1648.3ms
# Speed: 3.0ms preprocess, 1648.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1 referee, 1613.6ms
# Speed: 3.8ms preprocess, 1613.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 11 players, 1 referee, 1651.8ms
# Speed: 3.4ms preprocess, 1651.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 1 referee, 1621.1ms
# Speed: 3.6ms preprocess, 1621.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1635.9ms
# Speed: 4.1ms preprocess, 1635.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 1676.7ms
# Speed: 5.5ms preprocess, 1676.7ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 1720.9ms
# Speed: 5.2ms preprocess, 1720.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1787.7ms
# Speed: 6.9ms preprocess, 1787.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1824.1ms
# Speed: 5.4ms preprocess, 1824.1ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1642.2ms
# Speed: 7.0ms preprocess, 1642.2ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1847.4ms
# Speed: 19.9ms preprocess, 1847.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2173.9ms
# Speed: 3.5ms preprocess, 2173.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1953.3ms
# Speed: 6.5ms preprocess, 1953.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Processed 200/375 frames (0.34 FPS)
#
# 0: 384x640 1 ball, 14 players, 1743.4ms
# Speed: 4.2ms preprocess, 1743.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 1745.2ms
# Speed: 4.2ms preprocess, 1745.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 1868.7ms
# Speed: 25.0ms preprocess, 1868.7ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 1729.9ms
# Speed: 4.4ms preprocess, 1729.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 13 players, 1724.6ms
# Speed: 3.1ms preprocess, 1724.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1781.8ms
# Speed: 3.8ms preprocess, 1781.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1749.1ms
# Speed: 7.2ms preprocess, 1749.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1633.4ms
# Speed: 4.2ms preprocess, 1633.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 1762.4ms
# Speed: 7.8ms preprocess, 1762.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 1726.2ms
# Speed: 5.6ms preprocess, 1726.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1675.2ms
# Speed: 4.3ms preprocess, 1675.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1610.6ms
# Speed: 4.3ms preprocess, 1610.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 1651.9ms
# Speed: 4.3ms preprocess, 1651.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 1565.0ms
# Speed: 3.1ms preprocess, 1565.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 10 players, 1681.1ms
# Speed: 4.9ms preprocess, 1681.1ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 11 players, 1514.3ms
# Speed: 4.4ms preprocess, 1514.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 1587.2ms
# Speed: 5.7ms preprocess, 1587.2ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 1669.6ms
# Speed: 4.5ms preprocess, 1669.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 players, 1614.0ms
# Speed: 3.1ms preprocess, 1614.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 1597.3ms
# Speed: 4.4ms preprocess, 1597.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 players, 1628.7ms
# Speed: 4.5ms preprocess, 1628.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 players, 1499.9ms
# Speed: 7.1ms preprocess, 1499.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 players, 1615.2ms
# Speed: 3.6ms preprocess, 1615.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 players, 1555.2ms
# Speed: 9.1ms preprocess, 1555.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 10 players, 1700.7ms
# Speed: 6.3ms preprocess, 1700.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 9 players, 1530.2ms
# Speed: 5.3ms preprocess, 1530.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 9 players, 1567.4ms
# Speed: 3.2ms preprocess, 1567.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 8 players, 1670.3ms
# Speed: 8.0ms preprocess, 1670.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 8 players, 1564.3ms
# Speed: 3.9ms preprocess, 1564.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 11 players, 1527.4ms
# Speed: 7.2ms preprocess, 1527.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 13 players, 1574.6ms
# Speed: 3.0ms preprocess, 1574.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 1643.5ms
# Speed: 5.0ms preprocess, 1643.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 9 players, 1712.2ms
# Speed: 8.1ms preprocess, 1712.2ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 8 players, 1564.9ms
# Speed: 3.1ms preprocess, 1564.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 players, 1541.4ms
# Speed: 3.6ms preprocess, 1541.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 1509.0ms
# Speed: 7.6ms preprocess, 1509.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 10 players, 1649.0ms
# Speed: 3.5ms preprocess, 1649.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 players, 1615.5ms
# Speed: 3.7ms preprocess, 1615.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 10 players, 1568.4ms
# Speed: 2.5ms preprocess, 1568.4ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 9 players, 1673.4ms
# Speed: 3.1ms preprocess, 1673.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 8 players, 1582.3ms
# Speed: 6.8ms preprocess, 1582.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 7 players, 1531.2ms
# Speed: 3.6ms preprocess, 1531.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 7 players, 1498.1ms
# Speed: 2.9ms preprocess, 1498.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 8 players, 1502.6ms
# Speed: 5.3ms preprocess, 1502.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 8 players, 1483.5ms
# Speed: 3.6ms preprocess, 1483.5ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 1 goalkeeper, 7 players, 1516.3ms
# Speed: 3.7ms preprocess, 1516.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 8 players, 1523.2ms
# Speed: 6.1ms preprocess, 1523.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 8 players, 1471.5ms
# Speed: 3.5ms preprocess, 1471.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 1570.0ms
# Speed: 7.3ms preprocess, 1570.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 8 players, 1694.6ms
# Speed: 7.1ms preprocess, 1694.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Processed 250/375 frames (0.36 FPS)
#
# 0: 384x640 1 ball, 9 players, 1636.1ms
# Speed: 6.6ms preprocess, 1636.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 9 players, 1541.8ms
# Speed: 7.1ms preprocess, 1541.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 10 players, 1565.6ms
# Speed: 3.7ms preprocess, 1565.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 players, 1647.8ms
# Speed: 5.7ms preprocess, 1647.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 players, 1554.1ms
# Speed: 9.5ms preprocess, 1554.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 players, 1510.3ms
# Speed: 3.7ms preprocess, 1510.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 1536.9ms
# Speed: 6.2ms preprocess, 1536.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 9 players, 1725.4ms
# Speed: 5.8ms preprocess, 1725.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 10 players, 1546.0ms
# Speed: 4.2ms preprocess, 1546.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 10 players, 1567.4ms
# Speed: 3.5ms preprocess, 1567.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 9 players, 1618.0ms
# Speed: 2.9ms preprocess, 1618.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 8 players, 1610.3ms
# Speed: 4.2ms preprocess, 1610.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 9 players, 1544.5ms
# Speed: 6.8ms preprocess, 1544.5ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 9 players, 1550.9ms
# Speed: 5.5ms preprocess, 1550.9ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 8 players, 1662.3ms
# Speed: 3.0ms preprocess, 1662.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 players, 1634.2ms
# Speed: 3.7ms preprocess, 1634.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 players, 1707.6ms
# Speed: 4.0ms preprocess, 1707.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 10 players, 1575.9ms
# Speed: 6.8ms preprocess, 1575.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1675.8ms
# Speed: 3.6ms preprocess, 1675.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 1830.9ms
# Speed: 7.8ms preprocess, 1830.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 8 players, 1671.0ms
# Speed: 3.1ms preprocess, 1671.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 1574.2ms
# Speed: 3.6ms preprocess, 1574.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 1506.0ms
# Speed: 3.1ms preprocess, 1506.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 players, 1639.4ms
# Speed: 3.1ms preprocess, 1639.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 10 players, 1563.8ms
# Speed: 3.5ms preprocess, 1563.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 9 players, 1657.2ms
# Speed: 4.3ms preprocess, 1657.2ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 players, 1670.2ms
# Speed: 3.0ms preprocess, 1670.2ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 players, 1815.2ms
# Speed: 9.0ms preprocess, 1815.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 players, 1684.6ms
# Speed: 4.8ms preprocess, 1684.6ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 1541.1ms
# Speed: 6.2ms preprocess, 1541.1ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1655.1ms
# Speed: 5.4ms preprocess, 1655.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1600.0ms
# Speed: 3.0ms preprocess, 1600.0ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1662.9ms
# Speed: 3.6ms preprocess, 1662.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 1665.6ms
# Speed: 3.3ms preprocess, 1665.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 1680.9ms
# Speed: 2.9ms preprocess, 1680.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 1641.9ms
# Speed: 3.6ms preprocess, 1641.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1598.4ms
# Speed: 4.2ms preprocess, 1598.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1820.9ms
# Speed: 3.6ms preprocess, 1820.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 1772.6ms
# Speed: 6.8ms preprocess, 1772.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 1595.6ms
# Speed: 5.5ms preprocess, 1595.6ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 9 players, 1840.1ms
# Speed: 9.1ms preprocess, 1840.1ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1533.1ms
# Speed: 4.3ms preprocess, 1533.1ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1744.9ms
# Speed: 5.5ms preprocess, 1744.9ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 1763.6ms
# Speed: 3.6ms preprocess, 1763.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1581.3ms
# Speed: 3.0ms preprocess, 1581.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1683.5ms
# Speed: 4.3ms preprocess, 1683.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1776.5ms
# Speed: 7.8ms preprocess, 1776.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 14 players, 1775.3ms
# Speed: 8.5ms preprocess, 1775.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 13 players, 1709.7ms
# Speed: 9.4ms preprocess, 1709.7ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 14 players, 1690.0ms
# Speed: 8.8ms preprocess, 1690.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Processed 300/375 frames (0.37 FPS)
#
# 0: 384x640 1 goalkeeper, 15 players, 1971.7ms
# Speed: 7.4ms preprocess, 1971.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1902.9ms
# Speed: 3.7ms preprocess, 1902.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 13 players, 1721.7ms
# Speed: 15.3ms preprocess, 1721.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 14 players, 1626.3ms
# Speed: 4.0ms preprocess, 1626.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 14 players, 1707.3ms
# Speed: 6.5ms preprocess, 1707.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 17 players, 1763.1ms
# Speed: 6.4ms preprocess, 1763.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 18 players, 1946.3ms
# Speed: 3.4ms preprocess, 1946.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 14 players, 1926.5ms
# Speed: 7.3ms preprocess, 1926.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1879.9ms
# Speed: 3.1ms preprocess, 1879.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 14 players, 1827.3ms
# Speed: 6.2ms preprocess, 1827.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 14 players, 1664.8ms
# Speed: 4.9ms preprocess, 1664.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 18 players, 1672.3ms
# Speed: 3.0ms preprocess, 1672.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 15 players, 1858.6ms
# Speed: 16.8ms preprocess, 1858.6ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 15 players, 1702.2ms
# Speed: 6.5ms preprocess, 1702.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 13 players, 1739.6ms
# Speed: 5.0ms preprocess, 1739.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 14 players, 1687.4ms
# Speed: 3.7ms preprocess, 1687.4ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 1750.1ms
# Speed: 3.8ms preprocess, 1750.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 1721.5ms
# Speed: 3.5ms preprocess, 1721.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 16 players, 1628.8ms
# Speed: 7.9ms preprocess, 1628.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 13 players, 1726.7ms
# Speed: 3.0ms preprocess, 1726.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1659.3ms
# Speed: 3.7ms preprocess, 1659.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 1730.9ms
# Speed: 4.3ms preprocess, 1730.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1659.3ms
# Speed: 3.5ms preprocess, 1659.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1720.6ms
# Speed: 9.2ms preprocess, 1720.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1757.6ms
# Speed: 6.5ms preprocess, 1757.6ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 1724.8ms
# Speed: 11.6ms preprocess, 1724.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 1612.0ms
# Speed: 3.3ms preprocess, 1612.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 1537.2ms
# Speed: 3.7ms preprocess, 1537.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 10 players, 1767.5ms
# Speed: 3.6ms preprocess, 1767.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1712.9ms
# Speed: 3.6ms preprocess, 1712.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1584.3ms
# Speed: 4.9ms preprocess, 1584.3ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1671.1ms
# Speed: 5.9ms preprocess, 1671.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 1642.4ms
# Speed: 5.9ms preprocess, 1642.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 1697.4ms
# Speed: 3.8ms preprocess, 1697.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 players, 1505.9ms
# Speed: 3.3ms preprocess, 1505.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 players, 1550.4ms
# Speed: 6.1ms preprocess, 1550.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 players, 1589.8ms
# Speed: 8.3ms preprocess, 1589.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 players, 1674.0ms
# Speed: 3.1ms preprocess, 1674.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 players, 1562.2ms
# Speed: 5.6ms preprocess, 1562.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1607.3ms
# Speed: 7.8ms preprocess, 1607.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1789.6ms
# Speed: 6.5ms preprocess, 1789.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1577.8ms
# Speed: 6.0ms preprocess, 1577.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1622.7ms
# Speed: 8.3ms preprocess, 1622.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1611.2ms
# Speed: 7.2ms preprocess, 1611.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1650.7ms
# Speed: 4.4ms preprocess, 1650.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1563.4ms
# Speed: 2.5ms preprocess, 1563.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1766.7ms
# Speed: 3.1ms preprocess, 1766.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 1750.6ms
# Speed: 4.4ms preprocess, 1750.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1734.1ms
# Speed: 6.4ms preprocess, 1734.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 1796.3ms
# Speed: 7.0ms preprocess, 1796.3ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Processed 350/375 frames (0.37 FPS)
#
# 0: 384x640 10 players, 1624.1ms
# Speed: 8.9ms preprocess, 1624.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1636.4ms
# Speed: 5.1ms preprocess, 1636.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1636.5ms
# Speed: 4.2ms preprocess, 1636.5ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1730.0ms
# Speed: 5.2ms preprocess, 1730.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1656.0ms
# Speed: 6.2ms preprocess, 1656.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1790.0ms
# Speed: 3.8ms preprocess, 1790.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1797.9ms
# Speed: 3.7ms preprocess, 1797.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1750.3ms
# Speed: 2.7ms preprocess, 1750.3ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 1696.5ms
# Speed: 7.9ms preprocess, 1696.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 1651.6ms
# Speed: 3.7ms preprocess, 1651.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1601.1ms
# Speed: 3.6ms preprocess, 1601.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1771.9ms
# Speed: 3.6ms preprocess, 1771.9ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1706.4ms
# Speed: 8.9ms preprocess, 1706.4ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1667.8ms
# Speed: 7.4ms preprocess, 1667.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1594.5ms
# Speed: 3.7ms preprocess, 1594.5ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1822.6ms
# Speed: 7.5ms preprocess, 1822.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 1649.3ms
# Speed: 3.0ms preprocess, 1649.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1707.1ms
# Speed: 3.0ms preprocess, 1707.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1635.8ms
# Speed: 6.5ms preprocess, 1635.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1831.9ms
# Speed: 3.8ms preprocess, 1831.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 1803.0ms
# Speed: 3.1ms preprocess, 1803.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1577.5ms
# Speed: 8.0ms preprocess, 1577.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 1462.2ms
# Speed: 4.1ms preprocess, 1462.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1289.6ms
# Speed: 3.2ms preprocess, 1289.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1410.1ms
# Speed: 93.4ms preprocess, 1410.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] End of video reached.
# [INFO] Output video saved to: c:\Users\hp\OneDrive\Desktop\Player reidentification in sports footage\output_tracked_1749481939.mp4
# [INFO] Player log saved to: C:\Users\hp\OneDrive\Desktop\Player reidentification in sports footage\player_log.txt
# [INFO] All processing complete.
